# %%
import pandas as pd
# %matplotlib inline
#Imports pandas and the plot lib
#import matplotlib to graph the data
import matplotlib.pyplot as plt
df = pd.read_csv("Crime.csv")
#Reads the crime info excel into a variable
my_List=dict()
#Creates list
my_List= df.groupby("INCIDENTNEIGHBORHOOD")["INCIDENTNEIGHBORHOOD"].count()
#Organizes the list by neighborhoods and the sum of the crimes within the neighborhood. I created a quantity section in the excel and just added the sums of all of them
my_List.sort_values()[:50]
# Out:
# <ipython-input-1-d076b1aef4ae>:6: DtypeWarning: Columns (3,4,5,6,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Crime.csv")
# INCIDENTNEIGHBORHOOD
# Mt. Oliver Boro              93
# Mt. Oliver Neighborhood     117
# Outside County              211
# Troy Hill-Herrs Island      252
# Ridgemont                   274
# Chartiers City              287
# Outside State               303
# New Homestead               309
# East Carnegie               380
# Swisshelm Park              394
# Mount Oliver                453
# Summer Hill                 465
# Arlington Heights           488
# Hays                        502
# Regent Square               515
# Oakwood                     565
# Esplen                      609
# St. Clair                   620
# Glen Hazel                  689
# Fairywood                   708
# Windgap                     771
# Central Northside           786
# Spring Garden               834
# Polish Hill                 962
# Allegheny West              990
# Duquesne Heights           1023
# South Shore                1095
# West End                   1100
# Bon Air                    1107
# Terrace Village            1244
# Morningside                1380
# Upper Lawrenceville        1467
# Westwood                   1480
# Lincoln Place              1486
# Friendship                 1495
# Banksville                 1557
# Fineview                   1605
# California-Kirkbride       1621
# Stanton Heights            1665
# Upper Hill                 1717
# West Oakland               1729
# Beltzhoover                1817
# Troy Hill                  1837
# Arlington                  1882
# Outside City               1944
# Manchester                 1962
# Overbrook                  2008
# South Oakland              2121
# Spring Hill-City View      2172
# Lower Lawrenceville        2265
# Name: INCIDENTNEIGHBORHOOD, dtype: int64

# %% [markdown]
# This code imports pandas and matplotlib. It then reads the crime data from 2016 to present and adds one to every crime that happened in the neighborhood. I did this by adding a quantity column and adding one to every cell. This took two seconds with copy and paste and allows for easy addition.

# %%
my_List.sort_values()[:20].plot.bar()
plt.title('Crimes Per Neighborhood')
plt.xlabel('Neighborhoods')
plt.ylabel('Number of Crimes')
# Out:
# Text(0, 0.5, 'Number of Crimes')

# %% [markdown]
# This shows the top 20 neighborhoods that have the least amount of crime sense 2016. This graph clearly shows the safest neighborhoods.

# %%
my_List[:20].plot.bar()
plt.title('Crimes Per Neighborhood')
plt.xlabel('Neighborhoods')
plt.ylabel('Number of Crimes')
# Out:
# Text(0, 0.5, 'Number of Crimes')

# %% [markdown]
# This is the graph of the sum of the first 20 neighborhoods within the data set.

# %%
my_List.sort_values(ascending=[False])[:30].plot.bar()
plt.title('Crimes Per Neighborhood')
plt.xlabel('Neighborhoods')
plt.ylabel('Number of Crimes')
# Out:
# Text(0, 0.5, 'Number of Crimes')

# %% [markdown]
# This shows the 30 most dangerous neighborhoods within Pittsburgh.
